# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# %%
air = pd.read_csv("Air polltuon in top 10 city of indai in last 19 years.csv")

# %%
air.sample(10,random_state=2025)
# Out:
#      Unique ID       City       Date          Measure  Longitude   Latitude  \
# 511   01F5F8D4      Delhi 2015-03-01    PM2.5 (µg/m³)     77.125  28.703125
# 153   01F4C6B4      Delhi 2017-06-01        NO2 (ppb)     77.125  28.703125
# 872   00B65DC0    Chennai 2006-09-01        SO2 (ppb)     80.250  13.085938
# 1320  006456A4    Kolkata 2023-07-01     PM10 (µg/m³)     88.375  22.578125
# 1256  0018219C      Delhi 2006-11-01        NO2 (ppb)     77.125  28.703125
# 1371  00C01817     Mumbai 2016-11-01    PM2.5 (µg/m³)     72.875  19.078125
# 325   00F8EA33  Bengaluru 2009-01-01        NO2 (ppb)     77.625  12.968750
# 1275  01235074  Bengaluru 2011-06-01  Ozone (O3, ppb)     77.625  12.968750
# 1395  00333490  Bengaluru 2002-02-01    PM2.5 (µg/m³)     77.625  12.968750
# 1220  003EF1EE    Chennai 2016-05-01  Ozone (O3, ppb)     80.250  13.085938
#
#      Time Period Data Value Air Quality
# 511      Monthly         95    Moderate
# 153      Monthly          6        Good
# 872      Monthly         47    Moderate
# 1320     Monthly        155   Very Poor
# 1256     Monthly          6        Good
# 1371     Monthly        122        Poor
# 325      Monthly          7        Good
# 1275     Monthly         32        Good
# 1395     Monthly        123        Poor
# 1220     Monthly         89    Moderate

# %%
# Data Cleaning

# %%
air.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445 entries, 0 to 1444
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unique ID    1445 non-null   object
#  1   City         1445 non-null   category
#  2   Date         1445 non-null   datetime64[ns]
#  3   Measure      1445 non-null   category
#  4   Longitude    1445 non-null   float16
#  5   Latitude     1445 non-null   float16
#  6   Time Period  1445 non-null   category
#  7   Data Value   1445 non-null   int16
#  8   Air Quality  1445 non-null   category
# dtypes: category(4), datetime64[ns](1), float16(2), int16(1), object(1)
# memory usage: 107.5 KB

# %%
air.describe()
# Out:
#          Longitude     Latitude   Data Value
# count  1445.000000  1445.000000  1445.000000
# mean     79.241880    19.281400    73.802076
# std       5.141098     5.966944    54.812141
# min      72.877700    12.971600     5.000000
# 25%      77.102500    13.082700    29.000000
# 50%      77.594600    19.076000    55.000000
# 75%      80.270700    22.572600   111.000000
# max      88.363900    28.704100   200.000000

# %%
air = air.rename(
    columns = {"District":"City"})

# %%
air= air.astype(
    {"City":"category",
     "Measure":"category",
     "Data Value":"int16",
     "Air Quality":"category",
     "Longitude":"float16",
     "Latitude":"float16",
     "Time Period":"category"
    })

# %%
air["Date"] = pd.to_datetime(air["Date"],format="%d-%m-%Y")

# %%
# What is the trend of air pollution in the top 3 most polluted cities?

# %%
top_3 = air.groupby("City",observed=False)[["Data Value"]].mean().sort_values("Data Value",ascending=False).iloc[0:3].reset_index()
top_3
# Out:
#       City  Data Value
# 0    Delhi   77.193772
# 1  Chennai   75.550173
# 2   Mumbai   74.186851

# %%
air.loc[air["City"].isin (top_3["City"]),:].pivot_table(
    index = air["Date"].dt.year,
    columns = "City",
    values = "Data Value",
    aggfunc = "mean",
    observed = False
).plot().legend(bbox_to_anchor=(1,1))
plt.show()

# %%
# Which city has the highest average pollution level over the years?

# %%
air.groupby("City",observed=False)[["Data Value"]].mean().sort_values("Data Value",ascending=False).iloc[0]
# Out:
# Data Value    77.193772
# Name: Delhi, dtype: float64

# %%
# How does the standard deviation of pollution levels compare across cities?

# %%
air.groupby("City",observed=False)[["Data Value"]].std()
# Out:
#            Data Value
# City
# Bengaluru   52.593237
# Chennai     55.541824
# Delhi       57.151029
# Kolkata     52.887787
# Mumbai      55.838243

# %%
# What is the average pollution level for each pollutant across all cities?

# %%
air.pivot_table(
    index="City",
    columns = "Measure",
    values = "Data Value",
    aggfunc = "mean",
    observed=False
).round(2)
# Out:
# Measure    NO2 (ppb)  Ozone (O3, ppb)  PM10 (µg/m³)  PM2.5 (µg/m³)  SO2 (ppb)
# City
# Bengaluru      24.67            61.86        123.30         123.07      27.52
# Chennai        28.47            55.86        136.09         127.87      27.17
# Delhi          26.98            60.06        132.81         130.30      25.15
# Kolkata        29.21            60.76        125.30         122.70      25.77
# Mumbai         24.73            58.97        136.38         124.18      27.37

# %%
# Can we visualize the trend of air quality improvement or degradation over time?

# %%
air_quality = air.groupby(air["Date"].dt.year)[["Data Value"]].mean().round(2).reset_index()

# %%
y = []
for year in air_quality["Date"]:
    y.append(year)
v = []
for value in air_quality["Data Value"]:
    v.append(value)

length = len(y)
plt.figure(figsize=(12,6))
sns.lineplot(
    x = "Date",
    y="Data Value",
    data = air_quality,
    marker = "o",
    color = "g"
)
for a,b in zip(y,v):
    plt.text(a,b,str(b),ha="left",va="bottom",color="r")

plt.xlabel("Year")
plt.ylabel("Average Pollution Level")
plt.title("Average Pollution Level By Year")
plt.show()

# %%
# What is the correlation between different pollutants using a heatmap?

# %%
pollutants = air.pivot_table(
    index = "City",
    columns = "Measure",
    values = "Data Value",
    observed = False
)

# %%
pollutants_co = pollutants.corr()

# %%
sns.heatmap(data=pollutants_co,annot=True,cmap="coolwarm",fmt=".2f")
plt.show()

# %%
# How does the air quality vary seasonally? (Using boxplots)

# %%
season_conditions = [
    (air["Date"].dt.month .isin([12,1,2])),
    (air["Date"].dt.month .isin([3,4,5,6])),
    (air["Date"].dt.month .isin([7,8,9])),
    (air["Date"].dt.month .isin([10,11]))
]

# %%
season_output = ["Winter","Summer","Monsoon","Post-Monsoon"]

# %%
air["Season"] = np.select(season_conditions,season_output)

# %%
sns.boxplot(
    x="Season",
    y="Data Value",
    data=air,
    showmeans=True,meanprops={"marker":"*"},
    color="y",
    linewidth=2,
    order=["Winter","Summer","Monsoon","Post-Monsoon"])
plt.show()

# %%
# Which cities have the most stable pollution levels over the years?

# %%
air.pivot_table(
    index = air["Date"].dt.year,
    columns = "City",
    values = "Data Value",
    aggfunc = "mean",
    observed = False
).style.background_gradient(cmap="RdYlGn_r",axis=1)
# Out:
# <style type="text/css">
# #T_1b2f0_row0_col0 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_1b2f0_row0_col1, #T_1b2f0_row1_col1, #T_1b2f0_row2_col1, #T_1b2f0_row3_col1, #T_1b2f0_row4_col0, #T_1b2f0_row5_col3, #T_1b2f0_row6_col0, #T_1b2f0_row7_col4, #T_1b2f0_row8_col1, #T_1b2f0_row9_col4, #T_1b2f0_row10_col2, #T_1b2f0_row11_col1, #T_1b2f0_row12_col0, #T_1b2f0_row13_col4, #T_1b2f0_row14_col2, #T_1b2f0_row15_col3, #T_1b2f0_row16_col1, #T_1b2f0_row17_col1, #T_1b2f0_row18_col2, #T_1b2f0_row19_col3, #T_1b2f0_row20_col2, #T_1b2f0_row21_col1, #T_1b2f0_row22_col4, #T_1b2f0_row23_col3, #T_1b2f0_row24_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_1b2f0_row0_col2 {
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# #T_1b2f0_row0_col3, #T_1b2f0_row1_col0, #T_1b2f0_row2_col0, #T_1b2f0_row3_col3, #T_1b2f0_row4_col3, #T_1b2f0_row5_col4, #T_1b2f0_row6_col3, #T_1b2f0_row7_col0, #T_1b2f0_row8_col2, #T_1b2f0_row9_col1, #T_1b2f0_row10_col0, #T_1b2f0_row11_col2, #T_1b2f0_row12_col1, #T_1b2f0_row13_col1, #T_1b2f0_row14_col0, #T_1b2f0_row15_col4, #T_1b2f0_row16_col3, #T_1b2f0_row17_col3, #T_1b2f0_row18_col4, #T_1b2f0_row19_col2, #T_1b2f0_row20_col1, #T_1b2f0_row21_col3, #T_1b2f0_row22_col0, #T_1b2f0_row23_col2, #T_1b2f0_row24_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_1b2f0_row0_col4 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_1b2f0_row1_col2 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_1b2f0_row1_col3, #T_1b2f0_row16_col4, #T_1b2f0_row24_col1 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_1b2f0_row1_col4 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_1b2f0_row2_col2 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_1b2f0_row2_col3 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_1b2f0_row2_col4 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_1b2f0_row3_col0 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_1b2f0_row3_col2, #T_1b2f0_row6_col1 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_1b2f0_row3_col4 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_1b2f0_row4_col1 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_1b2f0_row4_col2 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_1b2f0_row4_col4 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_1b2f0_row5_col0, #T_1b2f0_row11_col3 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_1b2f0_row5_col1 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_1b2f0_row5_col2 {
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_1b2f0_row6_col2 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_1b2f0_row6_col4 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_1b2f0_row7_col1, #T_1b2f0_row9_col3 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_1b2f0_row7_col2 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_1b2f0_row7_col3, #T_1b2f0_row8_col4 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_1b2f0_row8_col0 {
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_1b2f0_row8_col3 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_1b2f0_row9_col0, #T_1b2f0_row23_col4 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_1b2f0_row9_col2 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_1b2f0_row10_col1, #T_1b2f0_row10_col4 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_1b2f0_row10_col3, #T_1b2f0_row14_col3 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_1b2f0_row11_col0 {
#   background-color: #dc3b2c;
#   color: #f1f1f1;
# }
# #T_1b2f0_row11_col4 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_1b2f0_row12_col2, #T_1b2f0_row20_col0 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_1b2f0_row12_col3 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_1b2f0_row12_col4 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_1b2f0_row13_col0 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_1b2f0_row13_col2, #T_1b2f0_row21_col4 {
#   background-color: #f36b42;
#   color: #f1f1f1;
# }
# #T_1b2f0_row13_col3 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_1b2f0_row14_col1 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_1b2f0_row14_col4 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_1b2f0_row15_col0 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_1b2f0_row15_col1 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_1b2f0_row15_col2 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_1b2f0_row16_col0 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_1b2f0_row16_col2 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_1b2f0_row17_col0 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_1b2f0_row17_col2 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_1b2f0_row17_col4 {
#   background-color: #60ba62;
#   color: #f1f1f1;
# }
# #T_1b2f0_row18_col0 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_1b2f0_row18_col1 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_1b2f0_row18_col3 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_1b2f0_row19_col0 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_1b2f0_row19_col1 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_1b2f0_row19_col4 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_1b2f0_row20_col3 {
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_1b2f0_row20_col4 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_1b2f0_row21_col0 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_1b2f0_row21_col2 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_1b2f0_row22_col1 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_1b2f0_row22_col2 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_1b2f0_row22_col3 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_1b2f0_row23_col0 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_1b2f0_row23_col1 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_1b2f0_row24_col3 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_1b2f0_row24_col4 {
#   background-color: #30a356;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1b2f0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >City</th>
#       <th id="T_1b2f0_level0_col0" class="col_heading level0 col0" >Bengaluru</th>
#       <th id="T_1b2f0_level0_col1" class="col_heading level0 col1" >Chennai</th>
#       <th id="T_1b2f0_level0_col2" class="col_heading level0 col2" >Delhi</th>
#       <th id="T_1b2f0_level0_col3" class="col_heading level0 col3" >Kolkata</th>
#       <th id="T_1b2f0_level0_col4" class="col_heading level0 col4" >Mumbai</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b2f0_level0_row0" class="row_heading level0 row0" >2000</th>
#       <td id="T_1b2f0_row0_col0" class="data row0 col0" >53.083333</td>
#       <td id="T_1b2f0_row0_col1" class="data row0 col1" >94.000000</td>
#       <td id="T_1b2f0_row0_col2" class="data row0 col2" >87.750000</td>
#       <td id="T_1b2f0_row0_col3" class="data row0 col3" >44.666667</td>
#       <td id="T_1b2f0_row0_col4" class="data row0 col4" >70.583333</td>
#     </tr>
#     <tr>
#       <th id="T_1b2f0_level0_row1" class="row_heading level0 row1" >2001</th>
#       <td id="T_1b2f0_row1_col0" class="data row1 col0" >55.416667</td>
#       <td id="T_1b2f0_row1_col1" class="data row1 col1" >77.083333</td>
#       <td id="T_1b2f0_row1_col2" class="data row1 col2" >65.416667</td>
#       <td id="T_1b2f0_row1_col3" class="data row1 col3" >67.583333</td>
#       <td id="T_1b2f0_row1_col4" class="data row1 col4" >73.166667</td>
#     </tr>
#     <tr>
#       <th id="T_1b2f0_level0_row2" class="row_heading level0 row2" >2002</th>
#       <td id="T_1b2f0_row2_col0" class="data row2 col0" >64.583333</td>
#       <td id="T_1b2f0_row2_col1" class="data row2 col1" >103.750000</td>
#       <td id="T_1b2f0_row2_col2" class="data row2 col2" >74.833333</td>
#       <td id="T_1b2f0_row2_col3" class="data row2 col3" >74.333333</td>

# %%
# Plot a time series analysis of pollution trends in Delhi.

# %%
delhi_trend = air.loc[air["City"] == "Delhi",:].groupby(air["Date"].dt.year)[["Data Value"]].mean().round(2).reset_index()

# %%
y = []
for years in delhi_trend["Date"]:
    y.append(years)
v = []
for value in delhi_trend["Data Value"]:
    v.append(value)

plt.figure(figsize=(10,6))
sns.lineplot(
    x = "Date",
    y = "Data Value",
    data = delhi_trend,
    color = "c"
)
for a,b in zip(y,v):
    plt.annotate(str(b),(a,b))
plt.show()

# %%
# What is the monthly distribution of air pollution levels?

# %%
month_wise_pollution = air.groupby(air["Date"].dt.strftime("%B"),observed = False)[["Data Value"]].mean().round(2).reset_index()

# %%
ex = []
for a in range(1,13,1):
    ex.append(a*0.0)
ex[6] = 0.1
ex[7] = 0.1    
plt.pie(
    x = month_wise_pollution["Data Value"],
    labels = month_wise_pollution["Date"],
    explode= ex,
    autopct= "%0.2f%%",
    startangle= 90
)
plt.show()

# %%
# How does pollution vary across latitude and longitude using scatter plots?

# %%
measure_filtered = air.loc[air["Measure"].str.startswith("PM10"),:]

# %%
sns.scatterplot(
    x = "Longitude",
    y = "Latitude",
    data = measure_filtered,
    c = measure_filtered["Data Value"],
    cmap = "coolwarm"
)
plt.show()

# %%
# What is the impact of festival seasons (Diwali, New Year) on pollution levels?

# %%
air.drop("Season",axis=1,inplace=True)

# %%
festive_season_conditions = [
    (air["Date"].dt.month .isin([10,11])),
    (air["Date"].dt.month .isin([12,1]))
]

# %%
festive_season_output = ["Diwali/Puja","New Year eve"]

# %%
air["Festive_Season"] = np.select(festive_season_conditions,festive_season_output,default="Normal")

# %%
festive_pollution = air.groupby("Festive_Season",observed=False)[["Data Value"]].mean().round(2).reset_index()

# %%
plt.pie(
    x = festive_pollution["Data Value"],
    labels = festive_pollution["Festive_Season"],
    autopct = "%0.2f%%",
    startangle=90,
    radius= 0.8,
    colors = ["r","y","g"]
)
plt.show()

# %%
# Plot a histogram of the distribution of different air quality categories.

# %%
sns.histplot(
    x = "Air Quality",
    data = air,
    color = "k"
)
plt.show()

# %%
# Identify the city with the cleanest air over the past 5 years.

# %%
air.loc[air["Date"].dt.year >= 2019,:].groupby("City",observed=False)[["Data Value"]].mean().reset_index().sort_values("Data Value")
# Out:
#         City  Data Value
# 1    Chennai   68.770492
# 0  Bengaluru   70.032787
# 2      Delhi   70.393443
# 4     Mumbai   75.245902
# 3    Kolkata   75.672131

# %%
# Compare NO₂ levels in industrial vs. non-industrial cities.

# %%
air["Industrial/Non-Industrial"] = np.where(air["City"]=="Bengaluru","Industrial","Non-Industrial")

# %%
air.loc[air["Measure"].str.startswith("NO2"),:].groupby("Industrial/Non-Industrial",observed=False)[["Data Value"]].mean().round(2)
# Out:
#                            Data Value
# Industrial/Non-Industrial
# Industrial                      24.67
# Non-Industrial                  27.31

# %%
# Can we detect any outliers in pollution data using boxplots?

# %%
# No

# %%
sns.boxplot(
    x = "Measure",
    y = "Data Value",
    data = air,
    color = "c",
    showmeans = True,
    linecolor = "k"
)
plt.show()

# %%
# How do different pollutants contribute to "Poor" air quality?

# %%
air.loc[air["Air Quality"] == "Poor",:].groupby("Measure",observed=False)[["Data Value"]].mean().round(2).fillna("Data Not Found")
# Out:
#                      Data Value
# Measure
# NO2 (ppb)        Data Not Found
# Ozone (O3, ppb)  Data Not Found
# PM10 (µg/m³)             126.79
# PM2.5 (µg/m³)            122.64
# SO2 (ppb)        Data Not Found

# %%
# Create a bar chart showing the worst air quality cities.

# %%
air.loc[air["Air Quality"] == "Poor",:].groupby("City",observed = False).agg(average_pollution_level=("Data Value","mean")).round(2).reset_index().sort_values("average_pollution_level").plot.barh(x="City")
plt.show()

# %%
# What are the top 3 months when pollution levels are at their peak?

# %%
air.groupby(air["Date"].dt.strftime("%B"),observed = False).agg(average_pollution_level = ("Data Value","mean")).round(2).sort_values("average_pollution_level",ascending = False).iloc[0:3]
# Out:
#           average_pollution_level
# Date
# March                       80.87
# October                     79.35
# November                    78.08
